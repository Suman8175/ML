# %%
import pandas as pd

# %% [markdown]
# # 1.Read from  CSV

# %% [markdown]
# **Local CSV**

# %%
# reading from csv which we have in our local system
pd.read_csv('data/placement.csv')
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %% [markdown]
# **Opening csv from URL**

# %%
import requests
from io import StringIO
#url and headers can be different others are same
url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# **Read TSV file(Tab Separated file)  with no headers**

# %%
#names paramter is to add header/column names for each
df=pd.read_csv('data/movies.tsv',sep='\t',names=['sno','names','relesase year','rating','no of ratings','genree'])
df
# Out:
#       sno                       names relesase year  rating  no of ratings  \
# 0      m0  10 things i hate about you          1999     6.9        62847.0
# 1      m1  1492: conquest of paradise          1992     6.2        10421.0
# 2      m2                  15 minutes          2001     6.1        25854.0
# 3      m3       2001: a space odyssey          1968     8.4       163227.0
# 4      m4                     48 hrs.          1982     6.9        22289.0
# ..    ...                         ...           ...     ...            ...
# 612  m612                    watchmen          2009     7.8       135229.0
# 613  m613                         xxx          2002     5.6        53505.0
# 614  m614                       x-men          2000     7.4       122149.0
# 615  m615          young frankenstein          1974     8.0        57618.0
# 616  m616                   zulu dawn          1979     6.4         1911.0
#
#                                                 genree
# ...

# %% [markdown]
# **Skip bad lines**</br>
# Suppose our row should have only 5 data but some row may have 7 or 4 or some other value.</br>
# In this case it will show parser error expected xxx fields in row no got yyy.

# %%
pd.read_csv('data/placement.csv',)
